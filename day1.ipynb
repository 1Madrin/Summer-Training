# %%
print("My Name is Mayank Kamboj\nI am a Student of Btech(IT) Studiying at ADGIPS\n")
# Out:
# My Name is Mayank Kamboj
# I am a Student of Btech(IT) Studiying at ADGIPS

# %%
#four types of strings
a = 'string with singel quotes'
b = "string with double quotes"
c = """String with 3 double quotes"""
d = '''String with 3 single quotes'''
print(f"{a}\n{b}\n{c}\n{d}")
# Out:
# string with singel quotes
# string with double quotes
# String with 3 double quotes
# String with 3 single quotes

# %%
print('this is Mayank\'s Laptop')
print("this is Mayank's Laptop")
print()
print("Mayank said \"How are you?\"")
print('Mayank said "How are you?"')
# Out:
# this is Mayank's Laptop
# this is Mayank's Laptop
#
# Mayank said "How are you?"
# Mayank said "How are you?"

# %%
a = "apple"
b = "ball"
print(a)
print(b)
# Out:
# apple
# ball

# %%
a = 10
b = 21
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a>b)
print(a==b)
print(a<b)
print(a!=b)
print(a<=b)
print(a>=b)
# Out:
# 31
# -11
# 210
# 0.47619047619047616
# 10
# 1000000000000000000000
# False
# False
# True
# True
# True
# False
# 31

# %%
name = "BBD"
age = 25
price = 99.5
print(name)
print(age)
print(price)
print(type(name))
print(type(age))
print(type(price))

print(type(input("enter your name: ")))
print(type(int(input("enter your age: "))))
# Out:
# BBD
# 25
# 99.5
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
# Out:
# 1. addition
# 2. subtraction
# 3. multiplication
# 4. division
#
#
#
# 30.0
